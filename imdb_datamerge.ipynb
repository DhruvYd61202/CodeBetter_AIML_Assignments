# %% [markdown]
# ### Merging Netflix Data with IMDB Dataset (titles and ratings) to perform EDA!

# %%
import pandas as pd

# %%
## Loading IMDB Data
basics = pd.read_csv("title.basics.tsv.gz", sep='\t', na_values='\\N', low_memory=False)
ratings = pd.read_csv("title.ratings.tsv.gz", sep='\t', na_values='\\N', low_memory=False)

## Loading Netflix Data
netflix = pd.read_csv("netflix_titles.csv")

# %%
print("basics -> ",basics.columns)
print("\n\n\n\n")
print("ratings -> ", ratings.columns)
print("\n\n\n\n")
print("netflix -> ",  netflix.columns)
# Out:
# basics ->  Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')
#
#
#
#
#
# ratings ->  Index(['tconst', 'averageRating', 'numVotes'], dtype='object')
#
#
#
#
#
# netflix ->  Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Filtering IMDB for 'movie' and 'tvSeries'
imdb_movies_tv = basics[(basics['titleType'].isin(['movie','tvSeries']))].copy()


# Release years into int
imdb_movies_tv['startYear'] = pd.to_numeric(imdb_movies_tv['startYear'],errors='coerce')
netflix['release_year'] = pd.to_numeric(netflix['release_year'],errors='coerce')

# Clean titles for better match
netflix['title_clean'] = netflix['title'].str.lower().str.strip()
imdb_movies_tv['primaryTitle_clean'] = imdb_movies_tv['primaryTitle'].str.lower().str.strip()

# %%
# Merge on title and year
merged = pd.merge(netflix, imdb_movies_tv,
                  left_on=['title_clean', 'release_year'],
                  right_on=['primaryTitle_clean', 'startYear'],
                  how='inner')

# %%
merged = pd.merge(merged, ratings, on='tconst', how='left')

# %%
merged.head()
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s3  TV Show                         Ganglands
# 2      s4  TV Show             Jailbirds New Orleans
# 3      s7    Movie  My Little Pony: A New Generation
# 4      s8    Movie                           Sankofa
#
#                         director  \
# 0                Kirsten Johnson
# 1                Julien Leclercq
# 2                            NaN
# 3  Robert Cullen, José Luis Ucha
# 4                   Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 1  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 2                                                NaN
# 3  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 4  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                                NaN  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
#
#    release_year rating  duration  ...                      primaryTitle  \
# 0          2020  PG-13    90 min  ...              Dick Johnson Is Dead
# 1          2021  TV-MA  1 Season  ...                         Ganglands
# 2          2021  TV-MA  1 Season  ...             Jailbirds New Orleans
# 3          2021     PG    91 min  ...  My Little Pony: A New Generation
# 4          1993  TV-MA   125 min  ...                           Sankofa
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0              Dick Johnson Is Dead     0.0    2020.0     NaN             89
# 1                         Braqueurs     0.0    2021.0     NaN             44
# 2             Jailbirds New Orleans     0.0    2021.0     NaN            NaN
# 3  My Little Pony: A New Generation     0.0    2021.0     NaN             90
# 4                           Sankofa     0.0    1993.0     NaN            125
#
#                         genres                primaryTitle_clean  \
# 0  Biography,Documentary,Drama              dick johnson is dead
# 1           Action,Crime,Drama                         ganglands
# 2       Documentary,Reality-TV             jailbirds new orleans
# 3   Adventure,Animation,Comedy  my little pony: a new generation
# 4                        Drama                           sankofa
#
#    averageRating  numVotes
# 0            7.4    7477.0
# 1            7.2    4827.0
# 2            6.5     329.0
# 3            6.8    4859.0
# 4            7.0     876.0
#
# [5 rows x 25 columns]

# %%
merged.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'title_clean', 'tconst', 'titleType', 'primaryTitle', 'originalTitle',
#        'isAdult', 'startYear', 'endYear', 'runtimeMinutes', 'genres',
#        'primaryTitle_clean', 'averageRating', 'numVotes'],
#       dtype='object')

# %%
merged.to_csv('merged_title_ratings_onNetflix.csv')
